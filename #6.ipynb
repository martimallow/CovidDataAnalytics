# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import display_html, HTML

# %%
# Colocando alguns defaults para embelezar os plots!
plt.style.use('seaborn-colorblind')
plt.rcParams['figure.figsize']  = (18, 10)
plt.rcParams['axes.labelsize']  = 20
plt.rcParams['axes.titlesize']  = 20
plt.rcParams['legend.fontsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 20
plt.rcParams['lines.linewidth'] = 4

plt.rcParams['figure.figsize']  = (18, 10)

# %%
def display_side_by_side(*args):
    html_str=''
    for df in args:
        html_str+=df.to_html()
    display_html(html_str.replace('table','table style="display:inline"'),raw=True)

# %%
p2019_1 = pd.read_csv(r'pnad/pnad2019_1.csv', index_col=0)

# %%
p2019_2 = pd.read_csv(r'pnad/pnad2019_2.csv', index_col=0)

# %%
p2019_3 = pd.read_csv(r'pnad/pnad2019_3.csv', index_col=0)

# %%
p2019_4 = pd.read_csv(r'pnad/pnad2019_4.csv', index_col=0)

# %%
p2020_1 = pd.read_csv(r'pnad/pnad2020_1.csv', index_col=0)

# %%
selected = ['UF','Capital','RM_RIDE','UPA','Estrato','V1022','V1023','V1029','V2001','V2005','V2007','V2008','V2009','V20081','V20082','V2010','V3001','V3002','V3002A','V3009A','V4001','V4002','V4003','V4004','V4005','V4006A','V4007','V4008','V4009','V4010','V4012','V40121','V4013','V40132A','V4014','V4015','V40151','V4016','V40161','V40162','V40163','V4018','V4019','V4020','V4021','V4022','V4024','V4025','V4028','V4029','V4032','V403311','V403312','V403322','V40333','V403331','V4034','V403412','V403422','V4039','V4039C','V4040','V40401','V4041','V4043','V4044','V4045','V4046','V4047','V4048','V4049','V405012','V405022','V40503','V405031','V405112','V405121','V405122','V4056','V4056C','V4057','V405811','V405812','V405821','V405822','V40583','V405831','V40584','V405911','V405912','V405921','V405922','V4062','V4062C','VD2002','VD2003','VD4002','VD4009','VD4010','VD4011','VD4012','VD4013','VD4014','VD4015','VD4016','VD4017','VD4018','VD4019','VD4020','VD4031','VD4036']

# %%
#Curiosidade
#Selecionando variaveis de interesse
p2019_1[selected].shape
# Out:
# (553308, 111)

# %%
#V2009: Idade do morador
#VD4002: Pessoas ocupadas

# %%
#Selecionando pessoas ocupadas
p2019_1[p2019_1['VD4002'] == 1]

#Selecionando variaveis de interesse
p2019_1[['VD4002','V2009']]
# Out:
#       VD4002  V2009
# Ano
# 2019     1.0     44
# 2019     NaN     61
# 2019     NaN     26
# 2019     NaN     17
# 2019     NaN      6
# ...      ...    ...
# 2019     NaN     13
# 2019     1.0     34
# 2019     1.0     28
# 2019     NaN     11
# 2019     NaN      4
#
# [553308 rows x 2 columns]

# %%
#Combinando as ideias acima

# %%
faixa_etaria1 = p2019_1[['VD4002', 'V2009']][p2019_1['VD4002'] == 1].groupby('V2009').sum()

# %%
faixa_etaria2 = p2019_2[['VD4002', 'V2009']][p2019_2['VD4002'] == 1].groupby('V2009').sum()

# %%
faixa_etaria3 = p2019_3[['VD4002', 'V2009']][p2019_3['VD4002'] == 1].groupby('V2009').sum()

# %%
faixa_etaria4 = p2019_4[['VD4002', 'V2009']][p2019_4['VD4002'] == 1].groupby('V2009').sum()

# %%
faixa_etaria5 = p2020_1[['VD4002', 'V2009']][p2020_1['VD4002'] == 1].groupby('V2009').sum()

# %%
display_side_by_side(faixa_etaria1.describe(),faixa_etaria2.describe(),faixa_etaria3.describe(), faixa_etaria4.describe(), faixa_etaria5.describe())
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>VD4002</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>82.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>2821.743902</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>2347.693456</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>279.750000</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>2816.000000</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>5047.500000</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>6351.000000</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>VD4002</th>
#     </tr>
#   </thead>
# ...

# %%
plt.bar(faixa_etaria1.index,faixa_etaria1.VD4002)
plt.title('Ocupados por faixa etária 2019-1')
plt.ylabel('número de ocupados')
plt.xlabel('idade')
plt.xticks(np.arange(0,max(df.index),5))
plt.xlim(0,100)
plt.show()

plt.bar(faixa_etaria2.index,faixa_etaria2.VD4002)
plt.title('Ocupados por faixa etária 2019-2')
plt.ylabel('número de ocupados')
plt.xlabel('idade')
plt.xticks(np.arange(0,max(df.index),5))
plt.xlim(0,100)
plt.show()

plt.bar(faixa_etaria3.index,faixa_etaria3.VD4002)
plt.title('Ocupados por faixa etária 2019-3')
plt.ylabel('número de ocupados')
plt.xlabel('idade')
plt.xticks(np.arange(0,max(df.index),5))
plt.xlim(0,100)
plt.show()

plt.bar(faixa_etaria4.index,faixa_etaria4.VD4002)
plt.title('Ocupados por faixa etária 2019-4')
plt.ylabel('número de ocupados')
plt.xlabel('idade')
plt.xticks(np.arange(0,max(df.index),5))
plt.xlim(0,100)
plt.show()

plt.bar(faixa_etaria5.index,faixa_etaria5.VD4002)
plt.title('Ocupados por faixa etária 2020-1')
plt.ylabel('número de ocupados')
plt.xlabel('idade')
plt.xticks(np.arange(0,max(df.index),5))
plt.xlim(0,100)
plt.show()

# %%
# Out:
# (231383, 218)
